# %% [markdown]
# # Amazon E commerce Data Analysis
#
# TODO- talk about EDA
# TODO- talk about the dataset
#     -> Kaggle
#     -> E commerce data

# %% [markdown]
# # Data Preparation and Cleaning
#     -> Load the file using pandas
#     -> Look at some information about the data and columns
#     ->Fix any missing or incorrect values

# %%
import pandas as pd
df = pd.read_csv("amazon_ecommerce_1M.csv")
df
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 0       U356787     P39256  Electronics      Mobile      H&M  33090.51
# 1       U198246     P38657       Sports     Outdoor  Samsung   9368.97
# 2       U539898     P38893       Sports     Fitness      H&M  14756.85
# 3       U325772     P54118       Beauty      Makeup     Sony    668.83
# 4       U865179     P70217         Home       Decor     Sony  10881.29
# ...         ...        ...          ...         ...      ...       ...
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# ...

# %%
df.columns
# df.info()
# Out:
# Index(['user_id', 'product_id', 'category', 'subcategory', 'brand', 'price',
#        'discount', 'final_price', 'rating', 'review_count', 'stock',
#        'seller_id', 'seller_rating', 'purchase_date', 'shipping_time_days',
#        'location', 'device', 'payment_method', 'is_returned',
#        'delivery_status'],
#       dtype='str')

# %%
df.describe()

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# # Checking Delivery Status

# %%
df.delivery_status
df[df['delivery_status']== "Delivered"]
Delayed = df[df['delivery_status']== "Delayed"]

# %%
df.stock
df[df['stock']>200]

# %% [markdown]
#  High Price Product

# %%
Highest_price = df['price'].max()
print("Highest Price of product is ",Highest_price)
# Out:
# Highest Price of product is  79999.7

# %% [markdown]
# Heavely discounted product of the dataset

# %%
Heavy_Discount = df['discount'].max()
# Out:
# np.float64(70.0)

# %% [markdown]
# # Revenue
# #Findings
# -> Total Revenue
# -> Revenue by Category
# -> Revenue by sub-category
# -> Revenue by brand

# %%
print("Total revenue :", df['final_price'].sum())
# Out:
# Total revenue : 9938876984.900002

# %%
print("Revenue by Cateogory:",df.groupby('category')['final_price'].sum())
# Out:
# Revenue by Cateogory: category
# Beauty         3.759517e+08
# Clothing       3.290504e+08
# Electronics    6.579048e+09
# Home           1.529978e+09
# Sports         1.124849e+09
# Name: final_price, dtype: float64

# %%
print("Revenue by sub category: ",df.groupby('subcategory')['final_price'].sum())
# Out:
# Revenue by sub category:  subcategory
# Camera        1.631526e+09
# Cycling       3.728452e+08
# Decor         5.125229e+08
# Fitness       3.750556e+08
# Furniture     5.064581e+08
# Haircare      1.250617e+08
# Headphones    1.637538e+09
# Kids          1.104925e+08
# Kitchen       5.109966e+08
# Laptop        1.652686e+09
# Makeup        1.248112e+08
# Men           1.097601e+08
# Mobile        1.657298e+09
# Outdoor       3.769483e+08
# Skincare      1.260788e+08
# Women         1.087979e+08
# Name: final_price, dtype: float64

# %%
print("Revenue by brand: ",df.groupby('brand')['final_price'].sum())
# Out:
# Revenue by brand:  brand
# Adidas     8.280768e+08
# Apple      8.260040e+08
# Boat       8.277323e+08
# H&M        8.223380e+08
# HP         8.269937e+08
# LG         8.312689e+08
# Lenovo     8.346983e+08
# Nike       8.266456e+08
# Puma       8.253044e+08
# Samsung    8.315598e+08
# Sony       8.322272e+08
# Zara       8.260282e+08
# Name: final_price, dtype: float64
